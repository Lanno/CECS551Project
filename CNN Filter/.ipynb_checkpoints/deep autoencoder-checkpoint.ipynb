# %%
from matplotlib import pyplot as plt
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, MaxPooling1D, UpSampling1D
from keras.layers.convolutional import Conv1D, Conv2D
import medleydb as mdb
from scipy import signal
from scipy.io import wavfile
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load the mix

# %%
multitracks = mdb.load_multitracks(["Phoenix_ColliersDaughter"])

# %%
mix = next(multitracks)

# %%
sample_rate, mix_audio = wavfile.read(mix.mix_path)
mix_audio = mix_audio.mean(1)
mix_audio = mix_audio[sample_rate*8:int(-sample_rate*1.5)]

# %%
samples_per_period = 256
overlap = int(samples_per_period/2)

# %%
freqs, times, s_mix = signal.stft(mix_audio, fs=sample_rate, nfft=samples_per_period, 
                                         noverlap=overlap, nperseg=samples_per_period)

freqs = freqs[:-1]
s_mix = s_mix[:-1,:]

# %%
plt.pcolormesh(times, freqs, 20*np.log10(np.abs(s_mix)))
# Out:
# C:\Users\Nolan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log10
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Load the Flute

# %%
flutes = mdb.get_files_for_instrument("flute", [mix])

# %%
flute = next(flutes)

# %%
sample_rate, flute_audio = wavfile.read(flute)
flute_audio = flute_audio.mean(1)
flute_audio = flute_audio[sample_rate*8:int(-sample_rate*1.5)]

# %%
freqs, times, s_flute = signal.stft(flute_audio, fs=sample_rate, nfft=samples_per_period, 
                                           noverlap=overlap, nperseg=samples_per_period)

freqs = freqs[:-1]
s_flute = s_flute[:-1,:]

# %%
plt.pcolormesh(times, freqs, 20*np.log10(np.abs(s_flute)))

# %% [markdown]
# # Prepare the training data

# %%
#s_mix_train = s_mix.reshape(*s_mix.T.shape, 1)
#s_mix_train.shape

# %%
num_test  = int((sample_rate * 10)/samples_per_period)
num_train = s_mix.shape[1] - num_test
print(num_train, num_test)
# Out:
# 15175 430

# %%
mix_train = s_mix.T[:num_train,:,np.newaxis]
mix_train = np.concatenate((mix_train.real, mix_train.imag), axis=-1)
mix_train.shape
# Out:
# (15175, 512, 2)

# %%
flute_train = s_flute.T[:num_train,:,np.newaxis]
flute_train = np.concatenate((flute_train.real, flute_train.imag), axis=-1)
flute_train.shape
# Out:
# (15175, 512, 2)

# %%
mix_test = s_mix.T[-num_test:,:,np.newaxis]
mix_test = np.concatenate((mix_test.real, mix_test.imag), axis=-1)
mix_test.shape
# Out:
# (430, 512, 2)

# %%
flute_test = s_flute.T[-num_test:,:,np.newaxis]
flute_test = np.concatenate((flute_test.real, flute_test.imag), axis=-1)
flute_test.shape
# Out:
# (430, 512, 2)

# %%
model = Sequential()

model.add(Dense(64, input_shape=mix_train.shape[1:], activation="relu", name="Conv1D_1"))

model.add(Conv1D(2, 2, padding="same"))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Conv1D_1 (Dense)             (None, 512, 64)           192
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 512, 2)            258
# =================================================================
# Total params: 450
# Trainable params: 450
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile('adam', loss='mean_squared_error', metrics=['accuracy'])

# %%
history = model.fit(mix_train, flute_train, batch_size=200, epochs=1)
# Out:
# Epoch 1/1
# 15175/15175 [==============================] - 13s 826us/step - loss: 744.4021 - acc: 0.5976

# %%
results = model.evaluate(mix_test, flute_test)

print(model.metrics_names)
print(results)
# Out:
# 430/430 [==============================] - 0s 757us/step
# ['loss', 'acc']
# [534.9603462307953, 0.6338299410287724]

# %% [markdown]
# # Results

# %%
flute_prediction = model.predict(mix_test)
flute_prediction.shape
# Out:
# (430, 512, 2)

# %%
flute_prediction = np.sqrt((flute_prediction**2).sum(-1)).T

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3,sharey=True,figsize=(12, 4))

ax1.set_title("Target")
ax2.set_title("Prediction")
ax3.set_title("Input")

ax1.pcolormesh(times[-num_test:], freqs, 20*np.log10(np.abs(s_flute[:,-num_test:])))
ax2.pcolormesh(times[-num_test:], freqs, 20*np.log10(flute_prediction))
ax3.pcolormesh(times[-num_test:], freqs, 20*np.log10(np.abs(s_mix[:,-num_test:])))

# %%
target_error = ((s_flute[:,-num_test:] - flute_prediction)**2)
target_error.mean()
# Out:
# (350.5211336444936-54.92666418337045j)

# %%
input_error = ((s_mix[:,-num_test:] - flute_prediction)**2)
input_error.mean()
# Out:
# (217.50089617230236-50.395744765722924j)

# %%
fig, (ax1, ax2) = plt.subplots(1,2,sharey=True,figsize=(12, 4))

ax1.set_title("Target - Prediction")
ax2.set_title("Input - Prediction")

ax1.pcolormesh(times[-num_test:], freqs, 20*np.log10(np.abs(target_error)))
ax2.pcolormesh(times[-num_test:], freqs, 20*np.log10(np.abs(input_error)))
